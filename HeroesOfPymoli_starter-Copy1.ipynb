# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# Raw data file
file_to_load = "Resources/purchase_data.csv"

# Read purchasing file and store into pandas data frame
purchase_data = pd.read_csv(file_to_load)
list(purchase_data)

#purchase_data.reset_index("index", inplace=True)
#purchase_data
# Out:
# ['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price']

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
total = purchase_data["SN"].value_counts()
total.count()
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
PA = {}
PA = {'Number of Unique Items':[(purchase_data["Item Name"].value_counts()).count()], 
      'Average Price':[purchase_data["Price"].mean()],
     'Number of Purchases':[purchase_data["Purchase ID"].count()],
    'Total Revenue':[purchase_data["Price"].sum()]
    }
PA

PA2 = pd.DataFrame(PA)
PA2
# Out:
#    Average Price  Number of Purchases  Number of Unique Items  Total Revenue
# 0       3.050987                  780                     179        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
N = purchase_data["Item ID"].count()


gender_df = purchase_data.groupby(['Gender'])
gen_count = gender_df["Item ID"].count()

Per = (gen_count/N)*100


frame2 ={}
frame2 = {'Percentage of Players':Per, 
      'Total Count':gen_count
         }

PA3 = pd.DataFrame(frame2)
PA3
# Out:
#                        Percentage of Players  Total Count
# Gender
# Female                             14.487179          113
# Male                               83.589744          652
# Other / Non-Disclosed               1.923077           15

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, etc. by gender
#
#
# * For normalized purchasing, divide total purchase value by purchase count, by gender
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
APP = gender_df["Price"].mean()
TPV = gender_df["Price"].sum()
NP = purchase_data["Price"].sum()
NT = (TPV/NP)*100

frame3 ={}
frame3 = {'Purchase Count':gen_count, 
      'Average Purchase Price':APP,
          'Total Purchase Value':TPV,
          'Normalized Totals':NT
         }

PA4 = pd.DataFrame(frame3)
PA4
# Out:
#                        Average Purchase Price  Normalized Totals  \
# Gender
# Female                               3.203009          15.209033
# Male                                 3.017853          82.681940
# Other / Non-Disclosed                3.346000           2.109027
#
#                        Purchase Count  Total Purchase Value
# Gender
# Female                            113                361.94
# Male                              652               1967.64
# Other / Non-Disclosed              15                 50.19

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Establish bins for ages
age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, etc. in the table below
#
#
# * Calculate Normalized Purchasing
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data["Age_Bin"] = pd.cut(purchase_data["Age"], age_bins, labels=group_names)
purchase_data
df = purchase_data.groupby("Age_Bin")

count2 = df["Age_Bin"].count()


APP2 = df["Price"].mean()


TPV2 = df["Price"].sum()


NT2 = (TPV2/NP)*100

POP = (count2/576)*100



frame4 ={}
frame4 = {'Percentage of Players':POP, 
          'Total Count':count2,
          'Average Purchase Price':APP2,
          'Total Purchase Value':TPV2,
          'Normalized Totals':NT2
         }

PA5 = pd.DataFrame(frame4)
PA5
# Out:
#          Average Purchase Price  Normalized Totals  Percentage of Players  \
# Age_Bin
# <10                    3.353478           3.241070               3.993056
# 10-14                  2.956429           3.478487               4.861111
# 15-19                  3.035956          17.349996              23.611111
# 20-24                  3.052219          46.813768              63.368056
# 25-29                  2.900990          12.312114              17.534722
# 30-34                  2.931507           8.992466              12.673611
# 35-39                  3.601707           6.205222               7.118056
# 40+                    2.941538           1.606878               2.256944
#
#          Total Count  Total Purchase Value
# Age_Bin
# <10               23                 77.13
# 10-14             28                 82.78
# 15-19            136                412.89
# 20-24            365               1114.06
# 25-29            101                293.00
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
TS = purchase_data.groupby(['SN'])

TS_count = TS["Item ID"].count()


TS_APP = TS["Price"].mean()


TS_TPV = TS["Price"].sum()



frame5 ={}
frame5 = {
          'Total Count':TS_count,
          'Average Purchase Price':TS_APP,
          'Total Purchase Value':TS_TPV
         }

PA6 = pd.DataFrame(frame5)

PA6.sort_values('Total Purchase Value',ascending=False)
# Out:
#                Average Purchase Price  Total Count  Total Purchase Value
# SN
# Lisosia93                    3.792000            5                 18.96
# Idastidru52                  3.862500            4                 15.45
# Chamjask73                   4.610000            3                 13.83
# Iral74                       3.405000            4                 13.62
# Iskadarya95                  4.366667            3                 13.10
# Ilarin91                     4.233333            3                 12.70
# Ialallo29                    3.946667            3                 11.84
# Tyidaim51                    3.943333            3                 11.83
# Lassilsala30                 3.836667            3                 11.51
# Chadolyla44                  3.820000            3                 11.46
# Iri67                        3.790000            3                 11.37
# Inguron55                    3.703333            3                 11.11
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#Purchase Count	Item Price	Total Purchase Value

IN = purchase_data.groupby(['Item Name'])

IN_count = IN["Item ID"].count()


IN_APP = IN["Price"].mean()


IN_TPV = IN["Price"].sum()



frame6 ={}
frame6 = {
          'Purchase Count':IN_count,
          'Item Price':IN_APP,
          'Total Purchase Value':IN_TPV
         }

PA7 = pd.DataFrame(frame6)

PA7.sort_values('Purchase Count',ascending=False)
# Out:
#                                               Item Price  Purchase Count  \
# Item Name
# Final Critic                                    4.614615              13
# Oathbreaker, Last Hope of the Breaking Storm    4.230000              12
# Persuasion                                      3.221111               9
# Nirvana                                         4.900000               9
# Extraction, Quickblade Of Trembling Hands       3.530000               9
# Fiery Glass Crusader                            4.580000               9
# Pursuit, Cudgel of Necromancy                   1.020000               8
# Brutality Ivory Warmace                         2.420000               8
# Singed Scalpel                                  4.350000               8
# Shadow Strike, Glory of Ending Hope             3.160000               8
# Retribution Axe                                 2.220000               8
# Lightning, Etcher of the King                   4.230000               8
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
PA7.sort_values('Total Purchase Value',ascending=False)
# Out:
#                                               Item Price  Purchase Count  \
# Item Name
# Final Critic                                    4.614615              13
# Oathbreaker, Last Hope of the Breaking Storm    4.230000              12
# Nirvana                                         4.900000               9
# Fiery Glass Crusader                            4.580000               9
# Singed Scalpel                                  4.350000               8
# Lightning, Etcher of the King                   4.230000               8
# Extraction, Quickblade Of Trembling Hands       3.530000               9
# Glimmer, Ender of the Moon                      4.400000               7
# Winter's Bite                                   3.770000               8
# Persuasion                                      3.221111               9
# Wolf                                            3.540000               8
# Wolf, Promise of the Moonwalker                 4.480000               6
# ...
